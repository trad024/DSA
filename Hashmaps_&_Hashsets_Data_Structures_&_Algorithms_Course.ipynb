# %% [markdown]
# <a href="https://colab.research.google.com/github/trad024/DSA/blob/main/Hashmaps_%26_Hashsets_Data_Structures_%26_Algorithms_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hashsets

s = set()
print(s)
# Out:
# set()

# %%
# Add item into Set - O(1)
s.add(1)
s.add(2)
s.add(3)

print(s)
# Out:
# {1, 2, 3}

# %%
# Lookup if item in set - O(1)
if 1 not in s:
  print(True)

# %%
# Remove item from set - O(1)
s.remove(3)

print(s)
# Out:
# {1, 2}

# %%
# Set construction - O(S) - S is the length of the string
string = 'aaaaaaabbbbbbbbbbbccccccccceeeeeeeee'
sett = set(string)

sett
# Out:
# {'a', 'b', 'c', 'e'}

# %%
# Loop over items in set - O(n)
for x in s:
  print(x)
# Out:
# 1
# 2

# %%
# Hashmaps - Dictionaries

d = {'greg': 1, 'steve': 2, 'rob': 3}

print(d)
# Out:
# {'greg': 1, 'steve': 2, 'rob': 3}

# %%
# Add key:val in dictionary: O(1)
d['arsh'] = 4

print(d)
# Out:
# {'greg': 1, 'steve': 2, 'rob': 3, 'arsh': 4}

# %%
# Check for presence of key in dictionary: O(1)
if 'greg' in d:
  print(True)
# Out:
# True

# %%
# Check the value corresponding to a key in the dictionary: O(1)
print(d['greg'])
# Out:
# 1

# %%
# Loop over the key:val pairs of the dictionary: O(n)
for key, val in d.items():
  print(f'key {key}: val {val}')
# Out:
# key greg: val 1
# key steve: val 2
# key rob: val 3
# key arsh: val 4

# %%
# Defaultdict

from collections import defaultdict

default = defaultdict(list)

default[2]
# Out:
# []

# %%
default
# Out:
# defaultdict(list, {2: []})

# %%
# Counter
from collections import Counter

counter = Counter(string)

print(counter)
# Out:
# Counter({'b': 11, 'c': 9, 'e': 9, 'a': 7})
